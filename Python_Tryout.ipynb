# %% [markdown]
# <a href="https://colab.research.google.com/github/Alok-Senapati/Collab-Notebooks/blob/main/Python_Tryout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python --version
# Out:
# Python 3.12.12

# %%
# !pip install numpy

# %%
import numpy as np

# %%
# %%time
input = [x+1 for x in range(100000000)]
output = [x + 5 for x in input]
# Out:
# CPU times: user 8.09 s, sys: 4.96 s, total: 13.1 s
# Wall time: 13.2 s

# %%
# %%time
np_input = np.array(input)
np_input + 5
# Out:
# CPU times: user 7.12 s, sys: 1.09 s, total: 8.21 s
# Wall time: 8.23 s
# array([        6,         7,         8, ..., 100000003, 100000004,
#        100000005])
